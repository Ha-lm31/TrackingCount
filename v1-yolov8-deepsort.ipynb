# %% [markdown]
# # Before Running the Script Please Make Sure you Select the Run Time as GPU

# %% [markdown]
# # **Clone the Github Repo**

# %%
# !git clone https://github.com/Ha-lm31/Adapter-Traffic.git

# %% [markdown]
# # PATH CONFIGURATIONS

# %%
import os
from IPython.display import Image


BASE_PATH = '/kaggle/working/Adapter-Traffic'

# Mettre à jour tous les chemins en utilisant la base
HOME = os.path.join(BASE_PATH, 'ultralytics/yolo/v8/detect')


# Chemins pour les vidéos
save_path = os.path.join(BASE_PATH, 'runs/detect/train2/test2.mp4')
compressed_path = "/content/result_compressed.mp4"  # Ce chemin reste le même sur Colab/Kaggle

# Suppression de fichier
if os.path.exists(compressed_path):
    os.remove(compressed_path)

# %% [markdown]
# # **Import the Required Libraries**

# %%
from IPython.display import Image

# %%
# !pwd

# %% [markdown]
# ## Setting the Current Directory

# %%
yd = os.path.join(BASE_PATH, 'YOLOv8-DeepSORT-Object-Tracking')
# %cd {yd}

# %% [markdown]
# ## Install all the Dependencies

# %%
# !pip install -e '.[dev]'

# %% [markdown]
# ## Moving to the Required Directory

# %%
# %cd {HOME}

# %% [markdown]
# ## Importing the Dataset from the RoboFlow

# %%
# !pip install roboflow

from roboflow import Roboflow

rf = Roboflow(api_key="9j4H4mvkoQZ7DQ8REN58")
project = rf.workspace("drone-dataset-mvh8i").project("detection-bzujh")
dataset = project.version(1).download("yolov5")

# %% [markdown]
# ## To implement the DeepSORT tracking, downloading the required files

# %%
# !gdown "https://drive.google.com/uc?id=11ZSZcG-bcbueXZC3rN08CM0qqX3eiHxf&confirm=t"

# %% [markdown]
# ## Unzipping the DeepSORT Files

# %%
# !unzip 'deep_sort_pytorch.zip'

# %% [markdown]
# # **Training the Custom Model**

# %%
# %cd {HOME}

# %%
# %cd {dataset.location}

# %%
# %cd {HOME}

# !python train.py model=yolov8l.pt data={dataset.location}/data.yaml epochs=1 imgsz=640

# %% [markdown]
# # **Checking the Files inside the Train Folder**

# %%
train = os.path.join(BASE_PATH, '/runs/detect/train2')
# !ls {train}

# %% [markdown]
# # **Printing the Confusion Matrix**

# %%
# Chemins pour les images
confusion_matrix_path = os.path.join(BASE_PATH, 'runs/detect/train2/confusion_matrix.png')

# Afficher les images
Image(filename = confusion_matrix_path)

# %% [markdown]
# # **Printing the Training and the Validation Loss**

# %%
# Chemins pour les images
results_path = os.path.join(BASE_PATH, 'runs/detect/train2/results.png')

# Afficher les images
Image(filename = results_path, width = 600)

# %% [markdown]
# # **Printing the Model Prediction on Validation Batch**

# %%
# Chemins pour les images
val_pred_path = os.path.join(BASE_PATH, 'runs/detect/train2/val_batch2_pred.jpg')

# Afficher les images
Image(filename = val_pred_path, width = 600)

# %% [markdown]
# # **Downloading the Weights From the Google Drive**"

# %%
# %cd {HOME}

# %%
# !gdown "https://drive.google.com/uc?id=1VBAZtJ5uJMEsnyya_d0yMP6efBRQ8IX-&confirm=t"

# %% [markdown]
# # **Validate Custom Model**

# %%
# !pwd

# %%
# !python val.py model='best.pt' data={dataset.location}/data.yaml

# %% [markdown]
# # **Inference with Custom Model**

# %% [markdown]
# # **Demo Video 1**

# %%
# !gdown "https://drive.google.com/uc?id=1UUZUS76ylH5RjMSc9s4rITSYDTG5AHt0&confirm=t"

# %%
# !python predict.py model='best.pt' source='test4.mp4'

# %% [markdown]
# # **Display the Demo Video**

# %%
# !rm "/content/result_compressed.mp4"

# %%
from IPython.display import HTML
from base64 import b64encode
import os

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %% [markdown]
# # **Demo Video 2**

# %%
# !gdown "https://drive.google.com/uc?id=1MaH6dNoegFjwkhtedxXufn2UD7EPpF_w&confirm=t"

# %%
# !python predict.py model='best.pt' source='test2.mp4'

# %% [markdown]
# # **Display the Demo Video**

# %%
# !rm "/content/result_compressed.mp4"

# %%
from IPython.display import HTML
from base64 import b64encode
import os

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
